# %%
set1 = set([1,2,3,1,2,3])

# %%
set1
# Out:
# {1, 2, 3}

# %%
set1[0] # 집합에서는 불가능
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 set1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
l2 = list(set1)

# %%
l2[0]
# Out:
# 1

# %%
len(l2 )
# Out:
# 3

# %%
len(set1)
# Out:
# 3

# %%
dict1 = {'apple':'사과','boy':'소년'}

# %%
dict1
# Out:
# {'apple': '사과', 'boy': '소년'}

# %%
dict1.keys()
# Out:
# dict_keys(['apple', 'boy'])

# %%
dict1.values()
# Out:
# dict_values(['사과', '소년'])

# %%
for i in dict1:
    print(i)
# Out:
# apple
# boy

# %%
for k in dict1:
    print(dict1[k])
# Out:
# 사과
# 소년

# %%
dict1[1] # 불가능 k = 인덱스가 아니라 key이기 떄문에
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 dict1[1]
#
# KeyError: 1

# %%
for k in dict1:
    
    print(k, dict1[k])
# Out:
# apple 사과
# boy 소년

# %%
dict1.items() # 튜플 형태의 리스트
# Out:
# dict_items([('apple', '사과'), ('boy', '소년')])

# %%
for i in dict1.items():
    print(i)
# Out:
# ('apple', '사과')
# ('boy', '소년')

# %%
dict1['car'] = '자동차'

# %%
dict1
# Out:
# {'apple': '사과', 'boy': '소년', 'car': '자동차'}

# %%
dict1['apple']
# Out:
# '사과'

# %%
dict1.get('lion', '몰라')
# Out:
# '몰라'
