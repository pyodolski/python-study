# %%
import pandas as pd
import numpy as np

# %%
casts = pd.read_csv('cast.csv')

# %%
casts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75001 entries, 0 to 75000
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      75000 non-null  object
#  1   year       75001 non-null  int64
#  2   name       75001 non-null  object
#  3   type       75001 non-null  object
#  4   character  75001 non-null  object
#  5   n          46035 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 3.4+ MB

# %%
# 결측치, 결측값
# fillna, drpna
casts.n
# Out:
# 0        31.0
# 1        22.0
# 2        10.0
# 3         NaN
# 4         NaN
#          ...
# 74996    11.0
# 74997     NaN
# 74998    20.0
# 74999     NaN
# 75000    25.0
# Name: n, Length: 75001, dtype: float64

# %%
casts['n'].isnull() # 각각의 값에서 널값 확인
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 74996    False
# 74997     True
# 74998    False
# 74999     True
# 75000    False
# Name: n, Length: 75001, dtype: bool

# %%
casts[casts['n'].isnull()]
# Out:
#                         title  year                        name     type  \
# 3        Secret in Their Eyes  2015                     $hutter    actor
# 4                  Steve Jobs  2015                     $hutter    actor
# 5      Straight Outta Compton  2015                     $hutter    actor
# 6      Straight Outta Compton  2015                     $hutter    actor
# 7              For Thy Love 2  2009                Bee Moe $lim    actor
# ...                       ...   ...                         ...      ...
# 74984                    Ovum  2015  Christina Rosas Anastasiou  actress
# 74985                  7 avlu  2009         Evmorfia Anastasiou  actress
# 74993     I teliki apopliromi  2013         Mara Anastasopoulou  actress
# 74997       The Magician King  2004       Tiannah Anastassiades  actress
# 74999              Toxic Tutu  2016             Zoe Anastassiou  actress
#
#                            character   n
# 3                    2002 Dodger Fan NaN
# ...

# %%
casts[casts['n'].notnull()]
# Out:
#                                                    title  year  \
# 0                                         Closet Monster  2015
# 1                                        Suuri illusioni  1985
# 2                                    Battle of the Sexes  2017
# 8      Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 10                               When the Man Went South  2014
# ...                                                  ...   ...
# 74994                                         180 moires  2010
# 74995                                   Ama de se thelei  2009
# 74996                           Mia fora kai ena... moro  2011
# 74998                                 Festival of Lights  2010
# 75000                                    Fugitive Pieces  2007
#
#                              name     type               character     n
# 0                        Buffy #1    actor                 Buffy 4  31.0
# ...

# %%
casts.dropna(axis=1)
# Out:
#        year                        name     type                character
# 0      2015                    Buffy #1    actor                  Buffy 4
# 1      1985                      Homo $    actor                   Guests
# 2      2017                     $hutter    actor          Bobby Riggs Fan
# 3      2015                     $hutter    actor          2002 Dodger Fan
# 4      2015                     $hutter    actor  1988 Opera House Patron
# ...     ...                         ...      ...                      ...
# 74996  2011     Penelope Anastasopoulou  actress       Popi voulkanizater
# 74997  2004       Tiannah Anastassiades  actress  Unicycle Race Attendant
# 74998  2010             Zoe Anastassiou  actress       Guidance Counselor
# 74999  2016             Zoe Anastassiou  actress        Demon of Toxicity
# 75000  2007  Anastassia Anastassopoulou  actress             Laundry Girl
#
# [75001 rows x 4 columns]

# %%
casts.fillna('없음')
# Out:
#                           title  year                        name     type  \
# 0                Closet Monster  2015                    Buffy #1    actor
# 1               Suuri illusioni  1985                      Homo $    actor
# 2           Battle of the Sexes  2017                     $hutter    actor
# 3          Secret in Their Eyes  2015                     $hutter    actor
# 4                    Steve Jobs  2015                     $hutter    actor
# ...                         ...   ...                         ...      ...
# 74996  Mia fora kai ena... moro  2011     Penelope Anastasopoulou  actress
# 74997         The Magician King  2004       Tiannah Anastassiades  actress
# 74998        Festival of Lights  2010             Zoe Anastassiou  actress
# 74999                Toxic Tutu  2016             Zoe Anastassiou  actress
# 75000           Fugitive Pieces  2007  Anastassia Anastassopoulou  actress
#
#                      character     n
# ...

# %%
casts.n.fillna(method='ffill')
# Out:
# /var/folders/w5/5jlwhb5147q1pkd786zxj_zm0000gn/T/ipykernel_32805/1072772480.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   casts.n.fillna(method='ffill')
# 0        31.0
# 1        22.0
# 2        10.0
# 3        10.0
# 4        10.0
#          ...
# 74996    11.0
# 74997    11.0
# 74998    20.0
# 74999    20.0
# 75000    25.0
# Name: n, Length: 75001, dtype: float64

# %%
casts.n.ffill()
# Out:
# 0        31.0
# 1        22.0
# 2        10.0
# 3        10.0
# 4        10.0
#          ...
# 74996    11.0
# 74997    11.0
# 74998    20.0
# 74999    20.0
# 75000    25.0
# Name: n, Length: 75001, dtype: float64

# %%
casts.n.mean()
# Out:
# np.float64(16.814358640165093)

# %%
casts['n'].fillna(casts['n'].mean() / 2, inplace=True
                  )

# %%
casts.head(5)
# Out:
#                   title  year      name   type                character  \
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4
# 1       Suuri illusioni  1985    Homo $  actor                   Guests
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron
#
#            n
# 0  31.000000
# 1  22.000000
# 2  10.000000
# 3   8.407179
# 4   8.407179

# %%
casts.dropna(inplace=True)

# %%
# casts에서 영화제목 Maa로 시작하는 것을 모두 선택
ex_title = 'Maa dfa asdf afds'
'Maa' in ex_title # 맨앞이 아님
# Out:
# True

# %%
ex_title.startswith('Maa')
# Out:
# True

# %%
casts.title.str.startswith('Maa')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 74996    False
# 74997    False
# 74998    False
# 74999    False
# 75000    False
# Name: title, Length: 75000, dtype: bool

# %%
casts[casts.title.str.startswith('Maa')]
# Out:
#                              title  year                  name     type  \
# 1489                         Maaro  2011          Abbas (VIII)    actor
# 6695                    Maarek hob  2004          Robert Abyad    actor
# 17319                       Maalik  2016      Farhan Ally Agha    actor
# 21678        Maa on syntinen laulu  1973    Niiles-Jouni Aikio    actor
# 21680        Maa on syntinen laulu  1973            Uula Aikio    actor
# 22667             Maan Gaye Ustaad  1981                  Ajit    actor
# 22986                 Maa kap Phra  2006       Pisan Akaraseni    actor
# 32315                  Maathi Yosi  2010           Alex (CXIV)    actor
# 32429                     Maad Dad  2013             Lalu Alex    actor
# 37445                  Maala Yogam  1990                Aliyar    actor
# 45518        Maa Nanna Chiranjeevi  2010                Alutit    actor
# 50944                   Maarek hob  2004        Colette Abboud  actress
# ...

# %%
casts[casts['title'].str.contains('Star')]
# Out:
#                                                   title  year  \
# 263                                   Porn Star Zombies  2009
# 481    Bob Hope's All-Star Look at TV's Prime Time Wars  1980
# 482                   Dickie Roberts: Former Child Star  2003
# 1905                               The Last Starfighter  1984
# 1978                                       Starry Night  1999
# ...                                                 ...   ...
# 72735              Starship Valiant: The Ties That Bind  2017
# 73046                       Starting Out in the Evening  2007
# 73053                    Cultivision (Collapsing Stars)  2002
# 73063                                   Starsky & Hutch  2004
# 73158                                    The North Star  2016
#
#                   name     type         character          n
# 263          A.J. (XV)    actor           Trinity   6.000000
# 481       Willie Aames    actor           Himself   8.407179
# ...

# %%
casts.year.value_counts()
# Out:
# year
# 2016    3841
# 2015    3438
# 2014    3309
# 2013    3110
# 2012    3011
#         ...
# 2019      16
# 1913      10
# 2020       4
# 1912       3
# 2023       3
# Name: count, Length: 110, dtype: int64
