# %%
s = set([1,2,3,4,5,6])

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
dict = {'사과' : 'apple', '배' : 'pear'}

# %%
dict
# Out:
# {'사과': 'apple', '배': 'pear'}

# %%
dict["사과"]
# Out:
# 'apple'

# %%
dict["오렌지"] = "orange"

# %%
dict
# Out:
# {'사과': 'apple', '배': 'pear', '오렌지': 'orange'}

# %%
dict.get("귤", "없음")
# Out:
# '없음'

# %%
dict.items()
# Out:
# dict_items([('사과', 'apple'), ('배', 'pear'), ('오렌지', 'orange')])

# %%
for item in dict.items():
    print (item)
# Out:
# ('사과', 'apple')
# ('배', 'pear')
# ('오렌지', 'orange')

# %%
"사과" in dict.keys()
# Out:
# True

# %%
"apple" in dict.values()
# Out:
# True

# %%
dict1 = all( value == "apple" for value in dict.values())

# %%
dict1
# Out:
# False

# %%
dict1 = any( value == "apple" for value in dict.values())

# %%
dict1
# Out:
# True
