# %%
# shift + enter = alt + enter // ctrl + enter
print("Hello world")
# Out:
# Hello world

# %%
abc = "대한민국"

# %%
abc
# Out:
# '대한민국'

# %%
type(abc)
# Out:
# str

# %%
str1 = f'나는 {abc} 사람입니다.'

# %%
print(str1)
# Out:
# 나는 대한민국 사람입니다.

# %%
l1 = [1 ,2, 3, 3.14, '영남대']

# %%
type(l1)
# Out:
# list

# %%
l1[3]
# Out:
# 3.14

# %%
l1[-1]
# Out:
# '영남대'

# %%
l1[-2]
# Out:
# 3.14

# %%
l1[3] = 31.4

# %%
l1
# Out:
# [1, 2, 3, 31.4, '영남대']

# %%
l1[1:3] # 마지막 것은 포함하지 않음
# Out:
# [2, 3]

# %%
l1[ : 3]
# Out:
# [1, 2, 3]

# %%
l1[1:]
# Out:
# [2, 3, 31.4, '영남대']

# %%
l1[:]
# Out:
# [1, 2, 3, 31.4, '영남대']

# %%
l2 = l1.copy() # 얕은 복사 하는 법 1

# %%
l2
# Out:
# [1, 2, 3, 31.4, '영남대']

# %%
l2[3] = 314

# %%
l2
# Out:
# [1, 2, 3, 314, '영남대']

# %%
l3 = l1

# %%
l3[2] = 1000

# %%
l3
# Out:
# [1, 2, 1000, 31.4, '영남대']

# %%
l1
# Out:
# [1, 2, 1000, 31.4, '영남대']

# %%
l2
# Out:
# [1, 2, 3, 314, '영남대']

# %%
l4 = l1[:] # 얕은 복사하는 법 2

# %%
l1
# Out:
# [1, 2, 1000, 31.4, '영남대']

# %%
l4[1] = 1000000

# %%
l1
# Out:
# [1, 2, 1000, 31.4, '영남대']

# %%
l4
# Out:
# [1, 1000000, 1000, 31.4, '영남대']

# %%
t1 = (1,2,3,4.14,'영남대')

# %%
t1[1]
# Out:
# 2

# %%
t1[1:3]
# Out:
# (2, 3)

# %%
# t1[1] = 1000 튜플은 불변의 데이터 타입

# %%
# l1.sort() 데이터 타입 동일 하지 않음

# %%
l5 = [3,5,4,2]

# %%
l5.sort()

# %%
l5
# Out:
# [2, 3, 4, 5]

# %%
sorted(l5)
# Out:
# [2, 3, 4, 5]

# %%
l6 = [5,4,3,2]

# %%
sorted(l6) # 정렬된 상태로 저장되지는 않고 보여주는 용도
# Out:
# [2, 3, 4, 5]

# %%
l6
# Out:
# [5, 4, 3, 2]
