# %% [markdown]
# 1.

# %% [markdown]
# ## 개념
#
# - plot
#
# - scatter
#
# - title(), xlabel(), ylabel() : 정해진 위치에 텍스트를 추가
#
# - text(): 임의의 위치에 텍스트를 추가
#
# - hist 히스토그램
#
# - axis : 범위 xm xma ym yma
#
# - grid 격자
#
# - anotate() : 주석달기 (그래프 자체에 주석을 달고 싶을 때) xy , xytext, arrowprops(화살표 속성)
#
# - ylim : 경계 생성
#
# - plit.xscale('log') : 스케일 변경 한쪽이 너무 클때 yscale (liner, symmetr;ic log, logit)
#
# - cumsum : 누적함 date_range 시계열 데이터

# %%
import matplotlib.pyplot as plt

# %%
x1 = [10,20,30]
y1 = [20,40,10]
x2 = [10,20,30]
y2 = [40,10,30]
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x1,y1,color='blue',linewidth=3,label='dotted', linestyle='dotted')
plt.plot(x2,y2,color='red',linewidth=3,label='dashed', linestyle='dashed')
plt.title("YU CSE")
plt.legend() # 레이블 정보 표시
plt.show()

# %%
plt.plot([1,3,2,10])
# 한글 사용 방법 한글 폰트 설정하는 방법
import matplotlib.font_manager as fm

# %%
font_list = fm.findSystemFonts()

# %%
font_list
# Out:
# ['/System/Library/AssetsV2/com_apple_MobileAsset_Font8/a304e3396d019087ab67af77f5e398977529007d.asset/AssetData/Libian.ttc',
#  '/System/Library/Fonts/Supplemental/Oriya MN.ttc',
#  '/System/Library/Fonts/Supplemental/NotoSansAdlam-Regular.ttf',
#  '/System/Library/AssetsV2/com_apple_MobileAsset_Font8/ee89e7987a76cc8cfdff36c96bd7bc77655b343e.asset/AssetData/YuGothic-Medium.otf',
#  '/System/Library/AssetsV2/com_apple_MobileAsset_Font8/99517f5220d46dff05d0dbb2a22d0036afefb089.asset/AssetData/YuMincho.ttc',
#  '/System/Library/Fonts/Supplemental/Gurmukhi.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansMro-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/Myanmar Sangam MN.ttc',
#  '/System/Library/Fonts/KohinoorGujarati.ttc',
#  '/System/Library/Fonts/Supplemental/Courier New Bold Italic.ttf',
#  '/System/Library/Fonts/Supplemental/Kailasa.ttc',
#  '/System/Library/Fonts/Supplemental/STIXSizTwoSymReg.otf',
#  '/System/Library/Fonts/SFCompactRounded.ttf',
# ...
