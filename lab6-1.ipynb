# %%
df.mean # 열
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.mean
#
# NameError: name 'df' is not defined

# %%
df.mean(1) # 열 방향으로 올라가면서 평균을 구함
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.mean(1)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=['2025-01-01','2025-01-01','2025-01-01','2025-01-01','2025-01-01','2025-01-01']).shift(2)

# %%
df.sub # 각 데이터에 대해 전부 연산 모양이 달라도 브로드캐스팅 떄문에 가능
df.apply(다른 함수의 이름) : 데이터에 함수 적용
# Out:
#   Cell In[11], line 2
#     df.apply(다른 함수의 이름) : 데이터에 함수 적용
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
s.value_count() # : 분포를 계산할 수 있음
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/w5/5jlwhb5147q1pkd786zxj_zm0000gn/T/ipykernel_28889/3669728615.py in ?()
# ----> 1 s.value_count() # : 분포를 계산할 수 있음
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
s
# Out:
# 2025-01-01    NaN
# 2025-01-01    NaN
# 2025-01-01    1.0
# 2025-01-01    3.0
# 2025-01-01    5.0
# 2025-01-01    NaN
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0    2
# 1    5
# 2    1
# 3    3
# 4    4
# 5    0
# 6    5
# 7    0
# 8    6
# 9    4
# dtype: int64>

# %%
str.lower()
pd.concat(조각들) axix 있고 합치는 함수

# %% [markdown]
# pd.merge(left,right, on=)
